# %%
import pandas as pd

# %%
x = pd.read_csv("anotacje adam - Hoja1.tsv", sep="\t")

# %%
x
# Out:
#                       image                SAT                NLX  \
# 0   ILSVRC2012_val_00000150          106,39,62        168,385,480
# 1   ILSVRC2012_val_00000235             27,178            214,460
# 2   ILSVRC2012_val_00000715            106,151         46,109,205
# 3   ILSVRC2012_val_00000838  42,83,300,232,394        399,153,464
# 4   ILSVRC2012_val_00000849      484,1,121,150              1,484
# 5   ILSVRC2012_val_00000992              27,83            436,153
# 6   ILSVRC2012_val_00001018        106,168,385  494, 46, 253, 205
# 7   ILSVRC2012_val_00001323           106,39,7              7,168
# 8   ILSVRC2012_val_00001350                106        106, 7, 385
# 9   ILSVRC2012_val_00001961                365      5,236,241,106
# 10  ILSVRC2012_val_00002019           39,312,7              168,7
# 11  ILSVRC2012_val_00002103           226, 250       283,226, 250
# 12  ILSVRC2012_val_00002111         106,151,27                428
# ...

# %%
list(eval(x.iloc[0]["SAT"]))
# Out:
# [106, 39, 62]
